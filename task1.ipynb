# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer='~/Downloads/heightC.txt', sep=' ', skiprows=2)
df
# Out:
#     gender  height  weight  momHeight  momWeight  dadHeight  dadWeight
# 1        1   63.00     112         65        115       67.5        145
# 2        1   63.00     125         61        120       70.0        160
# 3        1   66.00     130         63        115       69.0        170
# 4        1   62.00     110         60        115       70.0        180
# 5        1   63.00     140         62        170       70.0        185
# 6        1   64.00     120         67        115       71.0        180
# 7        1   66.00     120         65        140       70.0        175
# 8        1   61.00      99         62        110       65.0        165
# 9        1   68.00     180         66        140       73.0        270
# 10       1   68.00     160         65        120       72.0        170
# 11       1   64.75     122         60        114       67.0        134
# 12       1   67.00     160         64        160       71.0        170
# ...

# %%
df1 = df.loc[df["gender"] == 1]
df0 = df.loc[df["gender"] == 0]

# %% [markdown]
# df1 - dataframe with gender=1<br/>
# df0 - dataframe with gender=0

# %%
df1['height'].mean()
# Out:
# 64.734375

# %%
df1['height'][0:10].mean()
# Out:
# 64.4

# %%
df1['height'][0:2].mean()
# Out:
# 63.0

# %%
df['dadHeight'].mean()
# Out:
# 69.51515151515152

# %%
import matplotlib.pyplot as plt

# %%
#df1.plot(y='weight', style='o')

# %%
plt.plot(y=df1["weight"])
# Out:
# []
